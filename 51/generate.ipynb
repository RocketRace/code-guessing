# %%
import regex, grapheme
# external libs used for generating the bytes regex

# %%
import json 
data = json.load(open("categories.json"))
cat_pattern = data["regex"]
categories = data["classes"]
cat_pattern, categories
# Out:
# ('(?:\\p{Grapheme_Cluster_Break=CR}\\p{Grapheme_Cluster_Break=LF}|\\p{Grapheme_Cluster_Break=CR}|\\p{Grapheme_Cluster_Break=LF})|\\p{Grapheme_Cluster_Break=Control}|\\p{Grapheme_Cluster_Break=Prepend}*(?:(?:\\p{Grapheme_Cluster_Break=L}*(?:\\p{Grapheme_Cluster_Break=V}+|\\p{Grapheme_Cluster_Break=LV}\\p{Grapheme_Cluster_Break=V}*|\\p{Grapheme_Cluster_Break=LVT})\\p{Grapheme_Cluster_Break=T}*|\\p{Grapheme_Cluster_Break=L}+|\\p{Grapheme_Cluster_Break=T}+)|(?:\\p{Grapheme_Cluster_Break=RI}\\p{Grapheme_Cluster_Break=RI})|(?:\\p{Extended_Pictographic}(?:\\p{Grapheme_Cluster_Break=Extend}*\\p{Grapheme_Cluster_Break=ZWJ}\\p{Extended_Pictographic})*)|(?:\\p{InCB=Consonant}(?:(?:\\p{InCB=Extend}|\\p{InCB=Linker})*\\p{InCB=Linker}(?:\\p{InCB=Extend}|\\p{InCB=Linker})*\\p{InCB=Consonant})+)|[^\\p{Grapheme_Cluster_Break=Control}\\p{Grapheme_Cluster_Break=CR}\\p{Grapheme_Cluster_Break=LF}])(?:\\p{Grapheme_Cluster_Break=Extend}|\\p{Grapheme_Cluster_Break=ZWJ}|\\p{Grapheme_Cluster_Break=SpacingMark})*',
#  ['[^\\p{Grapheme_Cluster_Break=Control}\\p{Grapheme_Cluster_Break=CR}\\p{Grapheme_Cluster_Break=LF}]',
#   '\\p{Grapheme_Cluster_Break=CR}',
#   '\\p{Grapheme_Cluster_Break=LF}',
#   '\\p{Grapheme_Cluster_Break=Control}',
#   '\\p{Grapheme_Cluster_Break=Prepend}',
#   '\\p{Grapheme_Cluster_Break=L}',
#   '\\p{Grapheme_Cluster_Break=V}',
#   '\\p{Grapheme_Cluster_Break=LV}',
#   '\\p{Grapheme_Cluster_Break=LVT}',
#   '\\p{Grapheme_Cluster_Break=T}',
#   '\\p{Grapheme_Cluster_Break=RI}',
#   '\\p{Extended_Pictographic}',
#   '\\p{Grapheme_Cluster_Break=Extend}',
#   '\\p{Grapheme_Cluster_Break=ZWJ}',
#   '\\p{InCB=Consonant}',
#   '\\p{InCB=Extend}',
#   '\\p{InCB=Linker}',
#   '\\p{Grapheme_Cluster_Break=SpacingMark}'])

# %%
cat_chars: dict[str, list[str]] = {}
for category in categories:
    chars = []
    pat = regex.compile(category)
    
    lim = 0x110000 * 1
    for i in range(lim):
        try:
            chr(i).encode("utf-8")
            if regex.match(pat, chr(i)):
                chars.append(chr(i))
        except:
            pass
    cat_chars[category] = chars

# %%
{key: len(value) for key, value in cat_chars.items()}
# Out:
# {'[^\\p{Grapheme_Cluster_Break=Control}\\p{Grapheme_Cluster_Break=CR}\\p{Grapheme_Cluster_Break=LF}]': 1108169,
#  '\\p{Grapheme_Cluster_Break=CR}': 1,
#  '\\p{Grapheme_Cluster_Break=LF}': 1,
#  '\\p{Grapheme_Cluster_Break=Control}': 3893,
#  '\\p{Grapheme_Cluster_Break=Prepend}': 27,
#  '\\p{Grapheme_Cluster_Break=L}': 125,
#  '\\p{Grapheme_Cluster_Break=V}': 95,
#  '\\p{Grapheme_Cluster_Break=LV}': 399,
#  '\\p{Grapheme_Cluster_Break=LVT}': 10773,
#  '\\p{Grapheme_Cluster_Break=T}': 137,
#  '\\p{Grapheme_Cluster_Break=RI}': 26,
#  '\\p{Extended_Pictographic}': 3537,
#  '\\p{Grapheme_Cluster_Break=Extend}': 2130,
#  '\\p{Grapheme_Cluster_Break=ZWJ}': 1,
#  '\\p{InCB=Consonant}': 240,
#  '\\p{InCB=Extend}': 884,
#  '\\p{InCB=Linker}': 6,
#  '\\p{Grapheme_Cluster_Break=SpacingMark}': 395}

# %%
def find_ranges(xss: list[bytes]):
    if not xss:
        return []
    xs = sorted([x[0] for x in set(xss)])
    ranges = []
    start = prev = xs[0]
    for x in xs[1:]:
        if prev + 1 != x:
            ranges.append(range(start, prev + 1)) # exclusive
            start = x
        prev = x
    else:
        ranges.append(range(start, prev + 1))
    return ranges

def format_ranges(ranges: list[range]):
    return (b'[' if len(ranges) > 1 or (ranges and len(ranges[0]) > 1) else b'') + b''.join(
        bytes([range.start]) + b'-' + bytes([range.stop - 1])
        if len(range) > 2
        else bytes([range.start]) + bytes([range.stop - 1])
        if len(range) == 2
        else bytes([range.start])
        for range in ranges
    ) + (b']' if len(ranges) > 1 or (ranges and len(ranges[0]) > 1) else b'')

x = find_ranges([b"a", b"c", b"b", b"e"])
x, format_ranges(x)
# Out:
# ([range(97, 100), range(101, 102)], b'[a-ce]')

# %%
import re

def commonate_nonsingles(nonsingles: list[tuple[bytes, bytes]]):
    common_branches = {}
    for key, trail in nonsingles:
        common_branches.setdefault(trail, []).append(key)
    joins = [(
        branch,
        [key for key in keys if re.escape(key) == key],
        [key for key in keys if re.escape(key) != key]
    ) for branch, keys in common_branches.items()]
    merged = [(branch, 
               b'(?:' + format_ranges(find_ranges(safe)) + b'|' + b'|'.join(unsafe) + b')'
               if safe and unsafe else
               format_ranges(find_ranges(safe))
               if safe else
               b'(?:' + b'|'.join(unsafe) + b')'
               if len(unsafe) > 1 else unsafe[0]
    ) for branch, safe, unsafe in joins]
    return b'|'.join(keys + branch for branch, keys in merged)

# %%
def form_prefix_tree(*bins: bytes):
    prefix_tree = {}
    for bin in bins:
        if bin[0] in prefix_tree and bin[1:]:
            prefix_tree[bin[0]].append(bin[1:])
        elif bin[1:]:
            prefix_tree[bin[0]] = [bin[1:]]
        else:
            prefix_tree[bin[0]] = []
    # recurse
    return {i: form_prefix_tree(*cs) for i, cs in prefix_tree.items()}

def saturate(tree: dict):
    return {re.escape(bytes([key])): saturate(value) for key, value in tree.items()}


def prefix_to_regex(tree: dict):
    branches = [(key, prefix_to_regex(val)) for key, val in tree.items()]
    singles = [key for key, trail in branches if not trail and re.escape(key) == key]
    nonsingles = [(key, trail) for key, trail in branches if trail or re.escape(key) != key]
    single_ranges = format_ranges(find_ranges(singles))
    single_block = b"".join(singles)
    nonsingle_bundle = commonate_nonsingles(nonsingles)
    if singles and nonsingles:
        return b"(?:" + single_ranges + b'|' + nonsingle_bundle + b")"
    elif nonsingles:
        if len(nonsingles) == 1:
            return nonsingle_bundle
        else:
            return b"(?:" + nonsingle_bundle + b")"
    elif singles:
        if len(singles) == 1:
            return single_block
        else:
            return single_ranges
    else:
        return b''

def prefix_to_regex_old(tree: dict):
    return b'(?:' + b'|'.join(key + prefix_to_regex_old(val) for key, val in tree.items()) + b')'

def chars_union(*cs: str):
    prefix_tree = form_prefix_tree(*(c.encode("utf-8") for c in cs))
    # print(prefix_tree)
    # print(saturate(prefix_tree))
    result = prefix_to_regex(saturate(prefix_tree))
    result_old = prefix_to_regex_old(saturate(prefix_tree))

    # print(result)
    # result = b"(?:" + b"|".join(regexify(c) for c in cs) + b")"
    # print(result)
    print("initial", len(result_old), "final", len(result), "delta", len(result) - len(result_old))
    return result

chars_union(*"abあいうもやゆ+")
# Out:
# initial 73 final 26 delta -47
# b'(?:[ab]|\xe3(?:[\x81\x82][\x82\x84\x86])|\\+)'

# %%
cat_ranges = {cat.encode("utf-8"): chars_union(*chars) for cat, chars in cat_chars.items()}
{cat: len(union) for cat, union in cat_ranges.items()}
# Out:
# initial 6737001 final 502 delta -6736499
# initial 10 final 2 delta -8
# initial 10 final 2 delta -8
# initial 23759 final 140 delta -23619
# initial 255 final 73 delta -182
# initial 778 final 30 delta -748
# initial 603 final 41 delta -562
# initial 3292 final 404 delta -2888
# initial 65536 final 611 delta -64925
# initial 850 final 30 delta -820
# initial 174 final 8 delta -166
# initial 21650 final 371 delta -21279
# initial 13713 final 1477 delta -12236
# initial 19 final 3 delta -16
# initial 1503 final 97 delta -1406
# initial 5962 final 774 delta -5188
# initial 74 final 14 delta -60
# initial 2828 final 630 delta -2198
# {b'[^\\p{Grapheme_Cluster_Break=Control}\\p{Grapheme_Cluster_Break=CR}\\p{Grapheme_Cluster_Break=LF}]': 502,
#  b'\\p{Grapheme_Cluster_Break=CR}': 2,
#  b'\\p{Grapheme_Cluster_Break=LF}': 2,
#  b'\\p{Grapheme_Cluster_Break=Control}': 140,
#  b'\\p{Grapheme_Cluster_Break=Prepend}': 73,
#  b'\\p{Grapheme_Cluster_Break=L}': 30,
#  b'\\p{Grapheme_Cluster_Break=V}': 41,
#  b'\\p{Grapheme_Cluster_Break=LV}': 404,
#  b'\\p{Grapheme_Cluster_Break=LVT}': 611,
#  b'\\p{Grapheme_Cluster_Break=T}': 30,
#  b'\\p{Grapheme_Cluster_Break=RI}': 8,
#  b'\\p{Extended_Pictographic}': 371,
#  b'\\p{Grapheme_Cluster_Break=Extend}': 1477,
#  b'\\p{Grapheme_Cluster_Break=ZWJ}': 3,
#  b'\\p{InCB=Consonant}': 97,
#  b'\\p{InCB=Extend}': 774,
#  b'\\p{InCB=Linker}': 14,
#  b'\\p{Grapheme_Cluster_Break=SpacingMark}': 630}

# %%
bin_pattern = cat_pattern.encode("utf-8")
for cat, union in cat_ranges.items():
    bin_pattern = bin_pattern.replace(cat, union)

len(bin_pattern)
# Out:
# 8149

# %%
import re, grapheme

final_pattern = re.compile(bin_pattern)
s = " 😀😀😀👨‍👩‍👧‍👦👨‍👩‍👧‍👦😀😀"
len(final_pattern.findall(s.encode("utf-8"))), grapheme.length(s)
# Out:
# (8, 8)

# %%
line_width = 79
varname = "pattern"
offset = len(f"{varname} = (")
indent = len("    ")
delimiters = len("b''")

bin_remaining = ascii(bin_pattern)[2:-1]

undecorated = []
remaining_budget = line_width - indent - delimiters
initial_budget = line_width - offset - delimiters
initial_budget = remaining_budget

i = 0
while i < len(bin_remaining):
    budget = initial_budget if i == 0 else remaining_budget

    nudge = 0
    attempt = bin_remaining[i : i + budget - nudge]
    while True:
        try:
            eval("b'" + attempt + "'")
        except SyntaxError:
            nudge += 1
            attempt = bin_remaining[i : i + budget - nudge]
        else:
            break
    
    undecorated.append((attempt, nudge))
    i += len(attempt)


undecorated
# Out:
# [('(?:\\\\\\r\\\\\\n|\\\\\\r|\\\\\\n)|(?:[\\x00-\\x08\\x0e-\\x1f\\x7f]|(?:\\\\\\t|\\\\\\x0b|\\\\\\x0c',
#   0),
#  (')|\\xc2[\\x80-\\x9f\\xad]|\\xd8\\x9c|\\xe1\\xa0\\x8e|\\xe2(?:\\x80[\\x8b\\x8e\\x8f\\xa8',
#   0),
#  ('-\\xae]|\\x81[\\xa0-\\xaf])|\\xef(?:\\xbb\\xbf|\\xbf[\\xb0-\\xbb])|\\xf0(?:\\x93\\x90',
#   0),
#  ('[\\xb0-\\xbf]|\\x9b\\xb2[\\xa0-\\xa3]|\\x9d\\x85[\\xb3-\\xba])|\\xf3\\xa0(?:\\x80[',
#   3),
#  ('\\x80-\\x9f]|[\\x82\\x83\\x88-\\xbf][\\x80-\\xbf]|\\x87[\\xb0-\\xbf]))|(?:\\xd8[\\x80',
#   0),
#  ('-\\x85]|\\xdb\\x9d|\\xdc\\x8f|\\xe0(?:\\xa2[\\x90\\x91]|\\xa3\\xa2|\\xb5\\x8e)|\\xf0',
#   2),
#  ('\\x91(?:\\x82\\xbd|\\x83\\x8d|\\x87[\\x82\\x83]|\\xa4\\xbf|\\xa5\\x81|\\xa8\\xba|\\xaa[',
#   0),
#  ('\\x84-\\x89]|\\xb5\\x86|\\xbc\\x82))*(?:(?:(?:\\xe1(?:\\x84[\\x80-\\xbf]|\\x85[\\x80',
#   0),
#  ('-\\x9f])|\\xea\\xa5[\\xa0-\\xbc])*(?:(?:\\xe1(?:\\x85[\\xa0-\\xbf]|\\x86[\\x80-\\xa7',
#   0),
#  ('])|\\xed(?:\\x9e[\\xb0-\\xbf]|\\x9f[\\x80-\\x86]))+|(?:\\xea(?:[\\xb0\\xb7\\xbe][',
#   2),
#  ('\\x80\\x9c\\xb8]|[\\xb1\\xb8\\xbf][\\x94\\xb0]|[\\xb2\\xb9][\\x8c\\xa8]|[\\xb3\\xba][',
#   1),
#  ('\\x84\\xa0\\xbc]|[\\xb4\\xbb][\\x98\\xb4]|[\\xb5\\xbc][\\x90\\xac]|[\\xb6\\xbd][\\x88',
#   1),
#  ('\\xa4])|\\xeb(?:[\\x80\\x87\\x8e\\x95\\x9c\\xa3\\xaa\\xb1\\xb8\\xbf][\\x8c\\xa8]|[\\x81',
#   0),
#  ('\\x88\\x8f\\x96\\x9d\\xa4\\xab\\xb2\\xb9][\\x84\\xa0\\xbc]|[\\x82\\x89\\x90\\x97\\x9e',
#   3),
#  ('\\xa5\\xac\\xb3\\xba][\\x98\\xb4]|[\\x83\\x8a\\x91\\x98\\x9f\\xa6\\xad\\xb4\\xbb][\\x90',
#   1),
#  ('\\xac]|[\\x84\\x8b\\x92\\x99\\xa0\\xa7\\xae\\xb5\\xbc][\\x88\\xa4]|[\\x85\\x8c\\x93\\x9a',
#   0),
#  ('\\xa1\\xa8\\xaf\\xb6\\xbd][\\x80\\x9c\\xb8]|[\\x86\\x8d\\x94\\x9b\\xa2\\xa9\\xb0\\xb7',
#   3),
#  ('\\xbe][\\x94\\xb0])|\\xec(?:[\\x80\\x87\\x8e\\x95\\x9c\\xa3\\xaa\\xb1\\xb8\\xbf][\\x84',
#   1),
#  ('\\xa0\\xbc]|[\\x81\\x88\\x8f\\x96\\x9d\\xa4\\xab\\xb2\\xb9][\\x98\\xb4]|[\\x82\\x89\\x90',
#   0),
#  ('\\x97\\x9e\\xa5\\xac\\xb3\\xba][\\x90\\xac]|[\\x83\\x8a\\x91\\x98\\x9f\\xa6\\xad\\xb4',
#   3),
#  ('\\xbb][\\x88\\xa4]|[\\x84\\x8b\\x92\\x99\\xa0\\xa7\\xae\\xb5\\xbc][\\x80\\x9c\\xb8]|[',
#   2),
#  ('\\x85\\x8c\\x93\\x9a\\xa1\\xa8\\xaf\\xb6\\xbd][\\x94\\xb0]|[\\x86\\x8d\\x94\\x9b\\xa2',
#   3),
#  ('\\xa9\\xb0\\xb7\\xbe][\\x8c\\xa8])|\\xed(?:[\\x80\\x87\\x8e\\x95\\x9c][\\x98\\xb4]|[',
#   2),
#  ('\\x81\\x88\\x8f\\x96\\x9d][\\x90\\xac]|[\\x82\\x89\\x90\\x97][\\x88\\xa4]|[\\x83\\x8a',
#   2),
#  ('\\x91\\x98][\\x80\\x9c\\xb8]|[\\x84\\x8b\\x92\\x99][\\x94\\xb0]|[\\x85\\x8c\\x93\\x9a][',
#   0),
#  ('\\x8c\\xa8]|[\\x86\\x8d\\x94\\x9b][\\x84\\xa0\\xbc]|\\x9e\\x88))(?:\\xe1(?:\\x85[\\xa0',
#   0),
#  ('-\\xbf]|\\x86[\\x80-\\xa7])|\\xed(?:\\x9e[\\xb0-\\xbf]|\\x9f[\\x80-\\x86]))*|(?:',
#   3),
#  ('\\xea(?:[\\xb0\\xb7\\xbe][\\x81-\\x9b\\x9d-\\xb7\\xb9-\\xbf]|[\\xb1\\xb8\\xbf][\\x80-',
#   1),
#  ('\\x93\\x95-\\xaf\\xb1-\\xbf]|[\\xb2\\xb9][\\x80-\\x8b\\x8d-\\xa7\\xa9-\\xbf]|[\\xb3',
#   3),
#  ('\\xba][\\x80-\\x83\\x85-\\x9f\\xa1-\\xbb\\xbd-\\xbf]|[\\xb4\\xbb][\\x80-\\x97\\x99-',
#   3),
#  ('\\xb3\\xb5-\\xbf]|[\\xb5\\xbc][\\x80-\\x8f\\x91-\\xab\\xad-\\xbf]|[\\xb6\\xbd][\\x80-',
#   1),
#  ('\\x87\\x89-\\xa3\\xa5-\\xbf])|\\xeb(?:[\\x80\\x87\\x8e\\x95\\x9c\\xa3\\xaa\\xb1\\xb8',
#   3),
#  ('\\xbf][\\x80-\\x8b\\x8d-\\xa7\\xa9-\\xbf]|[\\x81\\x88\\x8f\\x96\\x9d\\xa4\\xab\\xb2\\xb9',
#   0),
#  ('][\\x80-\\x83\\x85-\\x9f\\xa1-\\xbb\\xbd-\\xbf]|[\\x82\\x89\\x90\\x97\\x9e\\xa5\\xac',
#   3),
#  ('\\xb3\\xba][\\x80-\\x97\\x99-\\xb3\\xb5-\\xbf]|[\\x83\\x8a\\x91\\x98\\x9f\\xa6\\xad\\xb4',
#   0),
#  ('\\xbb][\\x80-\\x8f\\x91-\\xab\\xad-\\xbf]|[\\x84\\x8b\\x92\\x99\\xa0\\xa7\\xae\\xb5\\xbc',
#   0),
#  ('][\\x80-\\x87\\x89-\\xa3\\xa5-\\xbf]|[\\x85\\x8c\\x93\\x9a\\xa1\\xa8\\xaf\\xb6\\xbd][',
#   2),
#  ('\\x81-\\x9b\\x9d-\\xb7\\xb9-\\xbf]|[\\x86\\x8d\\x94\\x9b\\xa2\\xa9\\xb0\\xb7\\xbe][\\x80',
#   0),
#  ('-\\x93\\x95-\\xaf\\xb1-\\xbf])|\\xec(?:[\\x80\\x87\\x8e\\x95\\x9c\\xa3\\xaa\\xb1\\xb8',
#   2),
#  ('\\xbf][\\x80-\\x83\\x85-\\x9f\\xa1-\\xbb\\xbd-\\xbf]|[\\x81\\x88\\x8f\\x96\\x9d\\xa4',
#   3),
#  ('\\xab\\xb2\\xb9][\\x80-\\x97\\x99-\\xb3\\xb5-\\xbf]|[\\x82\\x89\\x90\\x97\\x9e\\xa5\\xac',
#   0),
#  ('\\xb3\\xba][\\x80-\\x8f\\x91-\\xab\\xad-\\xbf]|[\\x83\\x8a\\x91\\x98\\x9f\\xa6\\xad\\xb4',
#   0),
#  ('\\xbb][\\x80-\\x87\\x89-\\xa3\\xa5-\\xbf]|[\\x84\\x8b\\x92\\x99\\xa0\\xa7\\xae\\xb5\\xbc',
#   0),
#  ('][\\x81-\\x9b\\x9d-\\xb7\\xb9-\\xbf]|[\\x85\\x8c\\x93\\x9a\\xa1\\xa8\\xaf\\xb6\\xbd][',
#   2),
#  ('\\x80-\\x93\\x95-\\xaf\\xb1-\\xbf]|[\\x86\\x8d\\x94\\x9b\\xa2\\xa9\\xb0\\xb7\\xbe][\\x80',
#   0),
#  ('-\\x8b\\x8d-\\xa7\\xa9-\\xbf])|\\xed(?:[\\x80\\x87\\x8e\\x95\\x9c][\\x80-\\x97\\x99-',
#   2),
#  ('\\xb3\\xb5-\\xbf]|[\\x81\\x88\\x8f\\x96\\x9d][\\x80-\\x8f\\x91-\\xab\\xad-\\xbf]|[\\x82',
#   0),
#  ('\\x89\\x90\\x97][\\x80-\\x87\\x89-\\xa3\\xa5-\\xbf]|[\\x83\\x8a\\x91\\x98][\\x81-\\x9b',
#   1),
#  ('\\x9d-\\xb7\\xb9-\\xbf]|[\\x84\\x8b\\x92\\x99][\\x80-\\x93\\x95-\\xaf\\xb1-\\xbf]|[',
#   3),
#  ('\\x85\\x8c\\x93\\x9a][\\x80-\\x8b\\x8d-\\xa7\\xa9-\\xbf]|[\\x86\\x8d\\x94\\x9b][\\x80-',
#   1),
#  ('\\x83\\x85-\\x9f\\xa1-\\xbb\\xbd-\\xbf]|\\x9e[\\x80-\\x87\\x89-\\xa3])))(?:\\xe1(?:',
#   2),
#  ('\\x86[\\xa8-\\xbf]|\\x87[\\x80-\\xbf])|\\xed\\x9f[\\x8b-\\xbb])*|(?:\\xe1(?:\\x84[',
#   2),
#  ('\\x80-\\xbf]|\\x85[\\x80-\\x9f])|\\xea\\xa5[\\xa0-\\xbc])+|(?:\\xe1(?:\\x86[\\xa8-',
#   2),
#  ('\\xbf]|\\x87[\\x80-\\xbf])|\\xed\\x9f[\\x8b-\\xbb])+)|(?:\\xf0\\x9f\\x87[\\xa6-\\xbf]',
#   0),
#  ('\\xf0\\x9f\\x87[\\xa6-\\xbf])|(?:(?:\\xc2[\\xa9\\xae]|\\xe2(?:\\x80\\xbc|\\x81\\x89|',
#   1),
#  ('\\x84[\\xa2\\xb9]|\\x86[\\x94-\\x99\\xa9\\xaa]|\\x8c[\\x9a\\x9b\\xa8]|\\x8e\\x88|\\x8f[',
#   0),
#  ('\\x8f\\xa9-\\xb3\\xb8-\\xba]|\\x93\\x82|\\x96[\\xaa\\xab\\xb6]|\\x97[\\x80\\xbb-\\xbe]|',
#   0),
#  ('\\x98[\\x80-\\x85\\x87-\\x92\\x94-\\xbf]|[\\x99\\x9b][\\x80-\\xbf]|\\x9a[\\x80-\\x85',
#   2),
#  ('\\x90-\\xbf]|\\x9c[\\x80-\\x85\\x88-\\x92\\x94\\x96\\x9d\\xa1\\xa8\\xb3\\xb4]|\\x9d[',
#   3),
#  ('\\x84\\x87\\x8c\\x8e\\x93-\\x95\\x97\\xa3-\\xa7]|\\x9e[\\x95-\\x97\\xa1\\xb0\\xbf]|\\xa4',
#   0),
#  ('[\\xb4\\xb5]|\\xac[\\x85-\\x87\\x9b\\x9c]|\\xad[\\x90\\x95])|\\xe3(?:\\x80[\\xb0\\xbd]',
#   0),
#  ('|\\x8a[\\x97\\x99])|\\xf0\\x9f(?:[\\x80-\\x83\\x8a-\\x8e\\x90-\\x93\\x96-\\x98\\x9a',
#   3),
#  ('\\x9b\\xa3\\xa6-\\xab\\xb0-\\xbe][\\x80-\\xbf]|\\x84[\\x8d-\\x8f\\xaf]|\\x85[\\xac-',
#   3),
#  ('\\xb1\\xbe\\xbf]|\\x86[\\x8e\\x91-\\x9a\\xad-\\xbf]|\\x87[\\x80-\\xa5]|\\x88[\\x81-',
#   3),
#  ('\\x8f\\x9a\\xaf\\xb2-\\xba\\xbc-\\xbf]|\\x89[\\x89-\\xbf]|\\x8f[\\x80-\\xba]|[\\x94',
#   3),
#  ('\\xbf][\\x80-\\xbd]|\\x95[\\x86-\\xbf]|\\x99[\\x80-\\x8f]|\\x9d[\\xb4-\\xbf]|\\x9f[',
#   2),
#  ('\\x95-\\xbf]|\\xa0[\\x8c-\\x8f]|\\xa1[\\x88-\\x8f\\x9a-\\x9f]|\\xa2[\\x88-\\x8f\\xae-',
#   1),
#  ('\\xbf]|\\xa4[\\x8c-\\xba\\xbc-\\xbf]|\\xa5[\\x80-\\x85\\x87-\\xbf]))(?:(?:\\xcc[\\x80',
#   0),
#  ('-\\xbf]|\\xcd[\\x80-\\xaf]|\\xd2[\\x83-\\x89]|\\xd6[\\x91-\\xbd\\xbf]|\\xd7[\\x81\\x82',
#   0),
#  ('\\x84\\x85\\x87]|\\xd8[\\x90-\\x9a]|\\xd9[\\x8b-\\x9f\\xb0]|\\xdb[\\x96-\\x9c\\x9f-',
#   3),
#  ('\\xa4\\xa7\\xa8\\xaa-\\xad]|\\xdc[\\x91\\xb0-\\xbf]|\\xdd[\\x80-\\x8a]|\\xde[\\xa6-',
#   3),
#  ('\\xb0]|\\xdf[\\xab-\\xb3\\xbd]|\\xe0(?:\\xa0[\\x96-\\x99\\x9b-\\xa3\\xa5-\\xa7\\xa9-',
#   2),
#  ('\\xad]|\\xa1[\\x99-\\x9b]|\\xa2[\\x98-\\x9f]|\\xa3[\\x8a-\\xa1\\xa3-\\xbf]|\\xa4[\\x80',
#   0),
#  ('-\\x82\\xba\\xbc]|\\xa5[\\x81-\\x88\\x8d\\x91-\\x97\\xa2\\xa3]|\\xa6[\\x81\\xbc\\xbe]|',
#   1),
#  ('\\xa7[\\x81-\\x84\\x8d\\x97\\xa2\\xa3\\xbe]|[\\xa8\\xaa][\\x81\\x82\\xbc]|\\xa9[\\x81',
#   2),
#  ('\\x82\\x87\\x88\\x8b-\\x8d\\x91\\xb0\\xb1\\xb5]|\\xab[\\x81-\\x85\\x87\\x88\\x8d\\xa2',
#   3),
#  ('\\xa3\\xba-\\xbf]|\\xac[\\x81\\xbc\\xbe\\xbf]|\\xad[\\x81-\\x84\\x8d\\x95-\\x97\\xa2',
#   3),
#  ('\\xa3]|\\xae[\\x82\\xbe]|\\xaf[\\x80\\x8d\\x97]|\\xb0[\\x80\\x84\\xbc\\xbe\\xbf]|\\xb1[',
#   0),
#  ('\\x80\\x86-\\x88\\x8a-\\x8d\\x95\\x96\\xa2\\xa3]|\\xb2[\\x81\\xbc\\xbf]|\\xb3[\\x82\\x86',
#   0),
#  ('\\x8c\\x8d\\x95\\x96\\xa2\\xa3]|\\xb4[\\x80\\x81\\xbb\\xbc\\xbe]|\\xb5[\\x81-\\x84\\x8d',
#   1),
#  ('\\x97\\xa2\\xa3]|\\xb6\\x81|\\xb7[\\x8a\\x8f\\x92-\\x94\\x96\\x9f]|\\xb8[\\xb1\\xb4-',
#   3),
#  ('\\xba]|\\xb9[\\x87-\\x8e]|\\xba[\\xb1\\xb4-\\xbc]|\\xbb[\\x88-\\x8e]|\\xbc[\\x98\\x99',
#   1),
#  ('\\xb5\\xb7\\xb9]|\\xbd[\\xb1-\\xbe]|\\xbe[\\x80-\\x84\\x86\\x87\\x8d-\\x97\\x99-\\xbc]|',
#   0),
#  ('\\xbf\\x86)|\\xe1(?:\\x80[\\xad-\\xb0\\xb2-\\xb7\\xb9\\xba\\xbd\\xbe]|\\x81[\\x98\\x99',
#   1),
#  ('\\x9e-\\xa0\\xb1-\\xb4]|\\x82[\\x82\\x85\\x86\\x8d\\x9d]|\\x8d[\\x9d-\\x9f]|\\x9c[\\x92',
#   0),
#  ('-\\x94\\xb2\\xb3]|\\x9d[\\x92\\x93\\xb2\\xb3]|\\x9e[\\xb4\\xb5\\xb7-\\xbd]|\\x9f[\\x86',
#   1),
#  ('\\x89-\\x93\\x9d]|\\xa0[\\x8b-\\x8d\\x8f]|\\xa2[\\x85\\x86\\xa9]|\\xa4[\\xa0-\\xa2\\xa7',
#   0),
#  ('\\xa8\\xb2\\xb9-\\xbb]|\\xa8[\\x97\\x98\\x9b]|\\xa9[\\x96\\x98-\\x9e\\xa0\\xa2\\xa5-',
#   3),
#  ('\\xac\\xb3-\\xbc\\xbf]|\\xaa[\\xb0-\\xbf]|\\xab[\\x80-\\x8e]|\\xac[\\x80-\\x83\\xb4-',
#   2),
#  ('\\xba\\xbc]|\\xad[\\x82\\xab-\\xb3]|\\xae[\\x80\\x81\\xa2-\\xa5\\xa8\\xa9\\xab-\\xad]|',
#   1),
#  ('\\xaf[\\xa6\\xa8\\xa9\\xad\\xaf-\\xb1]|\\xb0[\\xac-\\xb3\\xb6\\xb7]|\\xb3[\\x90-\\x92',
#   2),
#  ('\\x94-\\xa0\\xa2-\\xa8\\xad\\xb4\\xb8\\xb9]|\\xb7[\\x80-\\xbf])|\\xe2(?:\\x80\\x8c|',
#   3),
#  ('\\x83[\\x90-\\xb0]|\\xb3[\\xaf-\\xb1]|\\xb5\\xbf|\\xb7[\\xa0-\\xbf])|\\xe3(?:\\x80[',
#   2),
#  ('\\xaa-\\xaf]|\\x82[\\x99\\x9a])|\\xea(?:\\x99[\\xaf-\\xb2\\xb4-\\xbd]|\\x9a[\\x9e\\x9f',
#   0),
#  (']|\\x9b[\\xb0\\xb1]|\\xa0[\\x82\\x86\\x8b\\xa5\\xa6\\xac]|\\xa3[\\x84\\x85\\xa0-\\xb1',
#   2),
#  ('\\xbf]|\\xa4[\\xa6-\\xad]|\\xa5[\\x87-\\x91]|\\xa6[\\x80-\\x82\\xb3\\xb6-\\xb9\\xbc',
#   3),
#  ('\\xbd]|\\xa7\\xa5|\\xa8[\\xa9-\\xae\\xb1\\xb2\\xb5\\xb6]|\\xa9[\\x83\\x8c\\xbc]|\\xaa[',
#   1),
#  ('\\xb0\\xb2-\\xb4\\xb7\\xb8\\xbe\\xbf]|\\xab[\\x81\\xac\\xad\\xb6]|\\xaf[\\xa5\\xa8\\xad]',
#   0),
#  (')|\\xef(?:\\xac\\x9e|\\xb8[\\x80-\\x8f\\xa0-\\xaf]|\\xbe[\\x9e\\x9f])|\\xf0(?:\\x90(?',
#   0),
#  (':\\x87\\xbd|\\x8b\\xa0|\\x8d[\\xb6-\\xba]|\\xa8[\\x81-\\x83\\x85\\x86\\x8c-\\x8f\\xb8-',
#   1),
#  ('\\xba\\xbf]|\\xab[\\xa5\\xa6]|\\xb4[\\xa4-\\xa7]|\\xba[\\xab\\xac]|\\xbb[\\xbd-\\xbf]|',
#   0),
#  ('\\xbd[\\x86-\\x90]|\\xbe[\\x82-\\x85])|\\x91(?:\\x80[\\x81\\xb8-\\xbf]|\\x81[\\x80-',
#   2),
#  ('\\x86\\xb0\\xb3\\xb4\\xbf]|\\x82[\\x80\\x81\\xb3-\\xb6\\xb9\\xba]|\\x83\\x82|\\x84[\\x80',
#   0),
#  ('-\\x82\\xa7-\\xab\\xad-\\xb4]|\\x85\\xb3|\\x86[\\x80\\x81\\xb6-\\xbe]|\\x87[\\x89-\\x8c',
#   0),
#  ('\\x8f]|\\x88[\\xaf-\\xb1\\xb4\\xb6\\xb7\\xbe]|\\x89\\x81|\\x8b[\\x9f\\xa3-\\xaa]|\\x8c[',
#   0),
#  ('\\x80\\x81\\xbb\\xbc\\xbe]|\\x8d[\\x80\\x97\\xa6-\\xac\\xb0-\\xb4]|\\x90[\\xb8-\\xbf]|',
#   1),
#  ('\\x91[\\x82-\\x84\\x86\\x9e]|\\x92[\\xb0\\xb3-\\xb8\\xba\\xbd\\xbf]|\\x93[\\x80\\x82',
#   3),
#  ('\\x83]|\\x96[\\xaf\\xb2-\\xb5\\xbc\\xbd\\xbf]|\\x97[\\x80\\x9c\\x9d]|\\x98[\\xb3-\\xba',
#   1),
#  ('\\xbd\\xbf]|\\x99\\x80|\\x9a[\\xab\\xad\\xb0-\\xb5\\xb7]|\\x9c[\\x9d-\\x9f\\xa2-\\xa5',
#   2),
#  ('\\xa7-\\xab]|\\xa0[\\xaf-\\xb7\\xb9\\xba]|\\xa4[\\xb0\\xbb\\xbc\\xbe]|\\xa5\\x83|\\xa7[',
#   0),
#  ('\\x94-\\x97\\x9a\\x9b\\xa0]|\\xa8[\\x81-\\x8a\\xb3-\\xb8\\xbb-\\xbe]|\\xa9[\\x87\\x91-',
#   1),
#  ('\\x96\\x99-\\x9b]|\\xaa[\\x8a-\\x96\\x98\\x99]|\\xb0[\\xb0-\\xb6\\xb8-\\xbd\\xbf]|\\xb2',
#   0),
#  ('[\\x92-\\xa7\\xaa-\\xb0\\xb2\\xb3\\xb5\\xb6]|\\xb4[\\xb1-\\xb6\\xba\\xbc\\xbd\\xbf]|',
#   3),
#  ('\\xb5[\\x80-\\x85\\x87]|\\xb6[\\x90\\x91\\x95\\x97]|\\xbb[\\xb3\\xb4]|\\xbc[\\x80\\x81',
#   1),
#  ('\\xb6-\\xba]|\\xbd[\\x80\\x82])|\\x93\\x91[\\x80\\x87-\\x95]|\\x96(?:\\xab[\\xb0-\\xb4',
#   0),
#  (']|\\xac[\\xb0-\\xb6]|\\xbd\\x8f|\\xbe[\\x8f-\\x92]|\\xbf\\xa4)|\\x9b\\xb2[\\x9d\\x9e]|',
#   0),
#  ('\\x9c(?:\\xbc[\\x80-\\xad\\xb0-\\xbf]|\\xbd[\\x80-\\x86])|\\x9d(?:\\x85[\\xa5\\xa7-',
#   2),
#  ('\\xa9\\xae-\\xb2\\xbb-\\xbf]|\\x86[\\x80-\\x82\\x85-\\x8b\\xaa-\\xad]|\\x89[\\x82-\\x84',
#   0),
#  (']|\\xa8[\\x80-\\xb6\\xbb-\\xbf]|\\xa9[\\x80-\\xac\\xb5]|\\xaa[\\x84\\x9b-\\x9f\\xa1-',
#   2),
#  ('\\xaf])|\\x9e(?:\\x80[\\x80-\\x86\\x88-\\x98\\x9b-\\xa1\\xa3\\xa4\\xa6-\\xaa]|\\x82',
#   3),
#  ('\\x8f|\\x84[\\xb0-\\xb6]|\\x8a\\xae|[\\x8b\\x93][\\xac-\\xaf]|\\xa3[\\x90-\\x96]|\\xa5',
#   0),
#  ('[\\x84-\\x8a])|\\x9f\\x8f[\\xbb-\\xbf])|\\xf3\\xa0(?:\\x80[\\xa0-\\xbf]|[\\x81\\x84-',
#   1),
#  ('\\x86][\\x80-\\xbf]|\\x87[\\x80-\\xaf]))*\\xe2\\x80\\x8d(?:\\xc2[\\xa9\\xae]|\\xe2(?:',
#   0),
#  ('\\x80\\xbc|\\x81\\x89|\\x84[\\xa2\\xb9]|\\x86[\\x94-\\x99\\xa9\\xaa]|\\x8c[\\x9a\\x9b',
#   2),
#  ('\\xa8]|\\x8e\\x88|\\x8f[\\x8f\\xa9-\\xb3\\xb8-\\xba]|\\x93\\x82|\\x96[\\xaa\\xab\\xb6]|',
#   0),
#  ('\\x97[\\x80\\xbb-\\xbe]|\\x98[\\x80-\\x85\\x87-\\x92\\x94-\\xbf]|[\\x99\\x9b][\\x80-',
#   2),
#  ('\\xbf]|\\x9a[\\x80-\\x85\\x90-\\xbf]|\\x9c[\\x80-\\x85\\x88-\\x92\\x94\\x96\\x9d\\xa1',
#   2),
#  ('\\xa8\\xb3\\xb4]|\\x9d[\\x84\\x87\\x8c\\x8e\\x93-\\x95\\x97\\xa3-\\xa7]|\\x9e[\\x95-',
#   3),
#  ('\\x97\\xa1\\xb0\\xbf]|\\xa4[\\xb4\\xb5]|\\xac[\\x85-\\x87\\x9b\\x9c]|\\xad[\\x90\\x95])',
#   0),
#  ('|\\xe3(?:\\x80[\\xb0\\xbd]|\\x8a[\\x97\\x99])|\\xf0\\x9f(?:[\\x80-\\x83\\x8a-\\x8e',
#   3),
#  ('\\x90-\\x93\\x96-\\x98\\x9a\\x9b\\xa3\\xa6-\\xab\\xb0-\\xbe][\\x80-\\xbf]|\\x84[\\x8d-',
#   1),
#  ('\\x8f\\xaf]|\\x85[\\xac-\\xb1\\xbe\\xbf]|\\x86[\\x8e\\x91-\\x9a\\xad-\\xbf]|\\x87[\\x80',
#   0),
#  ('-\\xa5]|\\x88[\\x81-\\x8f\\x9a\\xaf\\xb2-\\xba\\xbc-\\xbf]|\\x89[\\x89-\\xbf]|\\x8f[',
#   2),
#  ('\\x80-\\xba]|[\\x94\\xbf][\\x80-\\xbd]|\\x95[\\x86-\\xbf]|\\x99[\\x80-\\x8f]|\\x9d[',
#   2),
#  ('\\xb4-\\xbf]|\\x9f[\\x95-\\xbf]|\\xa0[\\x8c-\\x8f]|\\xa1[\\x88-\\x8f\\x9a-\\x9f]|\\xa2',
#   0),
#  ('[\\x88-\\x8f\\xae-\\xbf]|\\xa4[\\x8c-\\xba\\xbc-\\xbf]|\\xa5[\\x80-\\x85\\x87-\\xbf]))',
#   0),
#  (')*)|(?:\\xe0(?:\\xa4[\\x95-\\xb9]|\\xa5[\\x98-\\x9f\\xb8-\\xbf]|\\xa6[\\x95-\\xa8',
#   3),
#  ('\\xaa-\\xb0\\xb2\\xb6-\\xb9]|\\xa7[\\x9c\\x9d\\x9f\\xb0\\xb1]|[\\xaa\\xac][\\x95-\\xa8',
#   1),
#  ('\\xaa-\\xb0\\xb2\\xb3\\xb5-\\xb9]|\\xab\\xb9|\\xad[\\x9c\\x9d\\x9f\\xb1]|\\xb0[\\x95-',
#   2),
#  ('\\xa8\\xaa-\\xb9]|\\xb1[\\x98-\\x9a]|\\xb4[\\x95-\\xba])(?:(?:(?:\\xcc[\\x80-\\xbf]|',
#   0),
#  ('\\xcd[\\x80-\\x8e\\x90-\\xaf]|\\xd2[\\x83-\\x87]|\\xd6[\\x91-\\xbd\\xbf]|\\xd7[\\x81',
#   2),
#  ('\\x82\\x84\\x85\\x87]|\\xd8[\\x90-\\x9a]|\\xd9[\\x8b-\\x9f\\xb0]|\\xdb[\\x96-\\x9c\\x9f',
#   0),
#  ('-\\xa4\\xa7\\xa8\\xaa-\\xad]|\\xdc[\\x91\\xb0-\\xbf]|\\xdd[\\x80-\\x8a]|\\xdf[\\xab-',
#   2),
#  ('\\xb3\\xbd]|\\xe0(?:\\xa0[\\x96-\\x99\\x9b-\\xa3\\xa5-\\xa7\\xa9-\\xad]|\\xa1[\\x99-',
#   2),
#  ('\\x9b]|\\xa2[\\x98-\\x9f]|\\xa3[\\x8a-\\xa1\\xa3-\\xbf]|[\\xa4\\xa6\\xa8\\xaa\\xac\\xb0',
#   0),
#  ('\\xb2]\\xbc|\\xa5[\\x91-\\x94]|\\xa7\\xbe|\\xb1[\\x95\\x96]|\\xb4[\\xbb\\xbc]|[\\xb8',
#   2),
#  ('\\xba][\\xb8-\\xba]|[\\xb9\\xbb][\\x88-\\x8b]|\\xbc[\\x98\\x99\\xb5\\xb7\\xb9]|\\xbd[',
#   1),
#  ('\\xb1\\xb2\\xb4\\xba-\\xbd]|\\xbe[\\x80\\x82-\\x84\\x86\\x87]|\\xbf\\x86)|\\xe1(?:\\x80',
#   0),
#  ('[\\xb7\\xb9\\xba]|\\x82\\x8d|\\x8d[\\x9d-\\x9f]|\\x9c\\x94|\\x9f[\\x92\\x9d]|\\xa2\\xa9',
#   0),
#  ('|\\xa4[\\xb9-\\xbb]|\\xa8[\\x97\\x98]|\\xa9[\\xa0\\xb5-\\xbc\\xbf]|\\xaa[\\xb0-\\xbd',
#   2),
#  ('\\xbf]|\\xab[\\x80-\\x8e]|\\xac\\xb4|\\xad[\\xab-\\xb3]|\\xae\\xab|\\xaf\\xa6|\\xb0',
#   3),
#  ('\\xb7|\\xb3[\\x90-\\x92\\x94-\\xa0\\xa2-\\xa8\\xad\\xb4\\xb8\\xb9]|\\xb7[\\x80-\\xbf])|',
#   0),
#  ('\\xe2(?:\\x80\\x8d|\\x83[\\x90-\\x9c\\xa1\\xa5-\\xb0]|\\xb3[\\xaf-\\xb1]|\\xb5\\xbf|',
#   2),
#  ('\\xb7[\\xa0-\\xbf])|\\xe3(?:\\x80[\\xaa-\\xaf]|\\x82[\\x99\\x9a])|\\xea(?:\\x99[\\xaf',
#   0),
#  ('\\xb4-\\xbd]|\\x9a[\\x9e\\x9f]|\\x9b[\\xb0\\xb1]|\\xa0\\xac|\\xa3[\\xa0-\\xb1]|\\xa4[',
#   1),
#  ('\\xab-\\xad]|\\xa6\\xb3|\\xaa[\\xb0\\xb2-\\xb4\\xb7\\xb8\\xbe\\xbf]|\\xab[\\x81\\xb6]|',
#   1),
#  ('\\xaf\\xad)|\\xef(?:\\xac\\x9e|\\xb8[\\xa0-\\xaf])|\\xf0(?:\\x90(?:\\x87\\xbd|\\x8b',
#   2),
#  ('\\xa0|\\x8d[\\xb6-\\xba]|\\xa8[\\x8d\\x8f\\xb8-\\xba\\xbf]|\\xab[\\xa5\\xa6]|\\xb4[',
#   3),
#  ('\\xa4-\\xa7]|\\xba[\\xab\\xac]|\\xbb[\\xbd-\\xbf]|\\xbd[\\x86-\\x90]|\\xbe[\\x82-\\x85',
#   0),
#  ('])|\\x91(?:\\x81[\\xb0\\xbf]|[\\x82\\xa0]\\xba|\\x84[\\x80-\\x82\\xb3\\xb4]|\\x85\\xb3',
#   0),
#  ('|\\x87\\x8a|\\x88\\xb6|\\x8b[\\xa9\\xaa]|\\x8c[\\xbb\\xbc]|\\x8d[\\xa6-\\xac\\xb0-\\xb4',
#   0),
#  (']|\\x91[\\x86\\x9e]|[\\x93\\xa5]\\x83|\\x97\\x80|\\x9a\\xb7|\\x9c\\xab|\\xa4\\xbe|\\xa8',
#   0),
#  ('\\xb4|\\xa9\\x87|\\xaa\\x99|\\xb5[\\x82\\x84\\x85]|\\xb6\\x97|\\xbd\\x82)|\\x96(?:\\xab',
#   0),
#  ('[\\xb0-\\xb4]|\\xac[\\xb0-\\xb6])|\\x9b\\xb2\\x9e|\\x9d(?:\\x85[\\xa5\\xa7-\\xa9\\xae-',
#   0),
#  ('\\xb2\\xbb-\\xbf]|\\x86[\\x80-\\x82\\x85-\\x8b\\xaa-\\xad]|\\x89[\\x82-\\x84])|\\x9e(?',
#   0),
#  (':\\x80[\\x80-\\x86\\x88-\\x98\\x9b-\\xa1\\xa3\\xa4\\xa6-\\xaa]|\\x82\\x8f|\\x84[\\xb0-',
#   1),
#  ('\\xb6]|\\x8a\\xae|[\\x8b\\x93][\\xac-\\xaf]|\\xa3[\\x90-\\x96]|\\xa5[\\x84-\\x8a])))|',
#   0),
#  ('\\xe0(?:[\\xa5\\xa7\\xab\\xad\\xb1\\xb5]\\x8d))*\\xe0(?:[\\xa5\\xa7\\xab\\xad\\xb1\\xb5',
#   0),
#  (']\\x8d)(?:(?:\\xcc[\\x80-\\xbf]|\\xcd[\\x80-\\x8e\\x90-\\xaf]|\\xd2[\\x83-\\x87]|',
#   3),
#  ('\\xd6[\\x91-\\xbd\\xbf]|\\xd7[\\x81\\x82\\x84\\x85\\x87]|\\xd8[\\x90-\\x9a]|\\xd9[\\x8b',
#   0),
#  ('-\\x9f\\xb0]|\\xdb[\\x96-\\x9c\\x9f-\\xa4\\xa7\\xa8\\xaa-\\xad]|\\xdc[\\x91\\xb0-\\xbf]',
#   0),
#  ('|\\xdd[\\x80-\\x8a]|\\xdf[\\xab-\\xb3\\xbd]|\\xe0(?:\\xa0[\\x96-\\x99\\x9b-\\xa3\\xa5-',
#   0),
#  ('\\xa7\\xa9-\\xad]|\\xa1[\\x99-\\x9b]|\\xa2[\\x98-\\x9f]|\\xa3[\\x8a-\\xa1\\xa3-\\xbf]|',
#   0),
#  ('[\\xa4\\xa6\\xa8\\xaa\\xac\\xb0\\xb2]\\xbc|\\xa5[\\x91-\\x94]|\\xa7\\xbe|\\xb1[\\x95',
#   3),
#  ('\\x96]|\\xb4[\\xbb\\xbc]|[\\xb8\\xba][\\xb8-\\xba]|[\\xb9\\xbb][\\x88-\\x8b]|\\xbc[',
#   2),
#  ('\\x98\\x99\\xb5\\xb7\\xb9]|\\xbd[\\xb1\\xb2\\xb4\\xba-\\xbd]|\\xbe[\\x80\\x82-\\x84\\x86',
#   0),
#  ('\\x87]|\\xbf\\x86)|\\xe1(?:\\x80[\\xb7\\xb9\\xba]|\\x82\\x8d|\\x8d[\\x9d-\\x9f]|\\x9c',
#   1),
#  ('\\x94|\\x9f[\\x92\\x9d]|\\xa2\\xa9|\\xa4[\\xb9-\\xbb]|\\xa8[\\x97\\x98]|\\xa9[\\xa0',
#   3),
#  ('\\xb5-\\xbc\\xbf]|\\xaa[\\xb0-\\xbd\\xbf]|\\xab[\\x80-\\x8e]|\\xac\\xb4|\\xad[\\xab-',
#   2),
#  ('\\xb3]|\\xae\\xab|\\xaf\\xa6|\\xb0\\xb7|\\xb3[\\x90-\\x92\\x94-\\xa0\\xa2-\\xa8\\xad',
#   3),
#  ('\\xb4\\xb8\\xb9]|\\xb7[\\x80-\\xbf])|\\xe2(?:\\x80\\x8d|\\x83[\\x90-\\x9c\\xa1\\xa5-',
#   2),
#  ('\\xb0]|\\xb3[\\xaf-\\xb1]|\\xb5\\xbf|\\xb7[\\xa0-\\xbf])|\\xe3(?:\\x80[\\xaa-\\xaf]|',
#   1),
#  ('\\x82[\\x99\\x9a])|\\xea(?:\\x99[\\xaf\\xb4-\\xbd]|\\x9a[\\x9e\\x9f]|\\x9b[\\xb0\\xb1]',
#   0),
#  ('|\\xa0\\xac|\\xa3[\\xa0-\\xb1]|\\xa4[\\xab-\\xad]|\\xa6\\xb3|\\xaa[\\xb0\\xb2-\\xb4',
#   3),
#  ('\\xb7\\xb8\\xbe\\xbf]|\\xab[\\x81\\xb6]|\\xaf\\xad)|\\xef(?:\\xac\\x9e|\\xb8[\\xa0-',
#   3),
#  ('\\xaf])|\\xf0(?:\\x90(?:\\x87\\xbd|\\x8b\\xa0|\\x8d[\\xb6-\\xba]|\\xa8[\\x8d\\x8f\\xb8',
#   0),
#  ('-\\xba\\xbf]|\\xab[\\xa5\\xa6]|\\xb4[\\xa4-\\xa7]|\\xba[\\xab\\xac]|\\xbb[\\xbd-\\xbf]',
#   0),
#  ('|\\xbd[\\x86-\\x90]|\\xbe[\\x82-\\x85])|\\x91(?:\\x81[\\xb0\\xbf]|[\\x82\\xa0]\\xba|',
#   1),
#  ('\\x84[\\x80-\\x82\\xb3\\xb4]|\\x85\\xb3|\\x87\\x8a|\\x88\\xb6|\\x8b[\\xa9\\xaa]|\\x8c[',
#   1),
#  ('\\xbb\\xbc]|\\x8d[\\xa6-\\xac\\xb0-\\xb4]|\\x91[\\x86\\x9e]|[\\x93\\xa5]\\x83|\\x97',
#   3),
#  ('\\x80|\\x9a\\xb7|\\x9c\\xab|\\xa4\\xbe|\\xa8\\xb4|\\xa9\\x87|\\xaa\\x99|\\xb5[\\x82\\x84',
#   0),
#  ('\\x85]|\\xb6\\x97|\\xbd\\x82)|\\x96(?:\\xab[\\xb0-\\xb4]|\\xac[\\xb0-\\xb6])|\\x9b',
#   3),
#  ('\\xb2\\x9e|\\x9d(?:\\x85[\\xa5\\xa7-\\xa9\\xae-\\xb2\\xbb-\\xbf]|\\x86[\\x80-\\x82\\x85',
#   0),
#  ('-\\x8b\\xaa-\\xad]|\\x89[\\x82-\\x84])|\\x9e(?:\\x80[\\x80-\\x86\\x88-\\x98\\x9b-\\xa1',
#   0),
#  ('\\xa3\\xa4\\xa6-\\xaa]|\\x82\\x8f|\\x84[\\xb0-\\xb6]|\\x8a\\xae|[\\x8b\\x93][\\xac-',
#   3),
#  ('\\xaf]|\\xa3[\\x90-\\x96]|\\xa5[\\x84-\\x8a])))|\\xe0(?:[\\xa5\\xa7\\xab\\xad\\xb1',
#   3),
#  ('\\xb5]\\x8d))*\\xe0(?:\\xa4[\\x95-\\xb9]|\\xa5[\\x98-\\x9f\\xb8-\\xbf]|\\xa6[\\x95-',
#   2),
#  ('\\xa8\\xaa-\\xb0\\xb2\\xb6-\\xb9]|\\xa7[\\x9c\\x9d\\x9f\\xb0\\xb1]|[\\xaa\\xac][\\x95-',
#   1),
#  ('\\xa8\\xaa-\\xb0\\xb2\\xb3\\xb5-\\xb9]|\\xab\\xb9|\\xad[\\x9c\\x9d\\x9f\\xb1]|\\xb0[',
#   3),
#  ('\\x95-\\xa8\\xaa-\\xb9]|\\xb1[\\x98-\\x9a]|\\xb4[\\x95-\\xba]))+)|(?:[!"%\\\',/->@-Z',
#   0),
#  ('_-z]|(?:\\\\ |\\\\#|\\\\$|\\\\&|\\\\(|\\\\)|\\\\*|\\\\+|\\\\-|\\\\.|\\\\?|\\\\[|\\\\\\\\|\\\\]|\\\\^|\\\\{',
#   0),
#  ('|\\\\||\\\\}|\\\\~)|\\xc2[\\xa0-\\xac\\xae-\\xbf]|[\\xc3-\\xd7\\xd9-\\xdf][\\x80-\\xbf]|',
#   1),
#  ('\\xd8[\\x80-\\x9b\\x9d-\\xbf]|\\xe0(?:[\\xa0-\\xbf][\\x80-\\xbf])|\\xe1(?:[\\x80-',
#   3),
#  ('\\x9f\\xa1-\\xbf][\\x80-\\xbf]|\\xa0[\\x80-\\x8d\\x8f-\\xbf])|\\xe2(?:\\x80[\\x80-',
#   3),
#  ('\\x8a\\x8c\\x8d\\x90-\\xa7\\xaf-\\xbf]|\\x81[\\x80-\\x9f\\xb0-\\xbf]|[\\x82-\\xbf][',
#   3),
#  ('\\x80-\\xbf])|[\\xe3-\\xec\\xee](?:[\\x80-\\xbf][\\x80-\\xbf])|\\xed(?:[\\x80-\\x9f]',
#   0),
#  ('[\\x80-\\xbf])|\\xef(?:[\\x80-\\xba\\xbc-\\xbe][\\x80-\\xbf]|\\xbb[\\x80-\\xbe]|\\xbf',
#   0),
#  ('[\\x80-\\xaf\\xbc-\\xbf])|\\xf0(?:[\\x90-\\x92\\x94-\\x9a\\x9c\\x9e-\\xbf](?:[\\x80-',
#   1),
#  ('\\xbf][\\x80-\\xbf])|\\x93(?:[\\x80-\\x8f\\x91-\\xbf][\\x80-\\xbf]|\\x90[\\x80-\\xaf]',
#   0),
#  (')|\\x9b(?:[\\x80-\\xb1\\xb3-\\xbf][\\x80-\\xbf]|\\xb2[\\x80-\\x9f\\xa4-\\xbf])|\\x9d(',
#   0),
#  ('?:[\\x80-\\x84\\x86-\\xbf][\\x80-\\xbf]|\\x85[\\x80-\\xb2\\xbb-\\xbf]))|[\\xf1\\xf2](',
#   0),
#  ('?:[\\x80-\\xbf](?:[\\x80-\\xbf][\\x80-\\xbf]))|\\xf3(?:[\\x80-\\x9f\\xa1-\\xbf](?:[',
#   0),
#  ('\\x80-\\xbf][\\x80-\\xbf])|\\xa0(?:\\x80[\\xa0-\\xbf]|[\\x81\\x84-\\x86][\\x80-\\xbf]',
#   0),
#  ('|\\x87[\\x80-\\xaf]))|\\xf4(?:[\\x80-\\x8f](?:[\\x80-\\xbf][\\x80-\\xbf]))))(?:(?:',
#   0),
#  ('\\xcc[\\x80-\\xbf]|\\xcd[\\x80-\\xaf]|\\xd2[\\x83-\\x89]|\\xd6[\\x91-\\xbd\\xbf]|\\xd7',
#   0),
#  ('[\\x81\\x82\\x84\\x85\\x87]|\\xd8[\\x90-\\x9a]|\\xd9[\\x8b-\\x9f\\xb0]|\\xdb[\\x96-',
#   3),
#  ('\\x9c\\x9f-\\xa4\\xa7\\xa8\\xaa-\\xad]|\\xdc[\\x91\\xb0-\\xbf]|\\xdd[\\x80-\\x8a]|\\xde',
#   0),
#  ('[\\xa6-\\xb0]|\\xdf[\\xab-\\xb3\\xbd]|\\xe0(?:\\xa0[\\x96-\\x99\\x9b-\\xa3\\xa5-\\xa7',
#   1),
#  ('\\xa9-\\xad]|\\xa1[\\x99-\\x9b]|\\xa2[\\x98-\\x9f]|\\xa3[\\x8a-\\xa1\\xa3-\\xbf]|\\xa4',
#   0),
#  ('[\\x80-\\x82\\xba\\xbc]|\\xa5[\\x81-\\x88\\x8d\\x91-\\x97\\xa2\\xa3]|\\xa6[\\x81\\xbc',
#   2),
#  ('\\xbe]|\\xa7[\\x81-\\x84\\x8d\\x97\\xa2\\xa3\\xbe]|[\\xa8\\xaa][\\x81\\x82\\xbc]|\\xa9[',
#   0),
#  ('\\x81\\x82\\x87\\x88\\x8b-\\x8d\\x91\\xb0\\xb1\\xb5]|\\xab[\\x81-\\x85\\x87\\x88\\x8d',
#   3),
#  ('\\xa2\\xa3\\xba-\\xbf]|\\xac[\\x81\\xbc\\xbe\\xbf]|\\xad[\\x81-\\x84\\x8d\\x95-\\x97',
#   3),
#  ('\\xa2\\xa3]|\\xae[\\x82\\xbe]|\\xaf[\\x80\\x8d\\x97]|\\xb0[\\x80\\x84\\xbc\\xbe\\xbf]|',
#   1),
#  ('\\xb1[\\x80\\x86-\\x88\\x8a-\\x8d\\x95\\x96\\xa2\\xa3]|\\xb2[\\x81\\xbc\\xbf]|\\xb3[',
#   3),
#  ('\\x82\\x86\\x8c\\x8d\\x95\\x96\\xa2\\xa3]|\\xb4[\\x80\\x81\\xbb\\xbc\\xbe]|\\xb5[\\x81-',
#   1),
#  ('\\x84\\x8d\\x97\\xa2\\xa3]|\\xb6\\x81|\\xb7[\\x8a\\x8f\\x92-\\x94\\x96\\x9f]|\\xb8[\\xb1',
#   0),
#  ('\\xb4-\\xba]|\\xb9[\\x87-\\x8e]|\\xba[\\xb1\\xb4-\\xbc]|\\xbb[\\x88-\\x8e]|\\xbc[\\x98',
#   0),
#  ('\\x99\\xb5\\xb7\\xb9]|\\xbd[\\xb1-\\xbe]|\\xbe[\\x80-\\x84\\x86\\x87\\x8d-\\x97\\x99-',
#   2),
#  ('\\xbc]|\\xbf\\x86)|\\xe1(?:\\x80[\\xad-\\xb0\\xb2-\\xb7\\xb9\\xba\\xbd\\xbe]|\\x81[',
#   3),
#  ('\\x98\\x99\\x9e-\\xa0\\xb1-\\xb4]|\\x82[\\x82\\x85\\x86\\x8d\\x9d]|\\x8d[\\x9d-\\x9f]|',
#   1),
#  ('\\x9c[\\x92-\\x94\\xb2\\xb3]|\\x9d[\\x92\\x93\\xb2\\xb3]|\\x9e[\\xb4\\xb5\\xb7-\\xbd]|',
#   1),
#  ('\\x9f[\\x86\\x89-\\x93\\x9d]|\\xa0[\\x8b-\\x8d\\x8f]|\\xa2[\\x85\\x86\\xa9]|\\xa4[\\xa0',
#   0),
#  ('-\\xa2\\xa7\\xa8\\xb2\\xb9-\\xbb]|\\xa8[\\x97\\x98\\x9b]|\\xa9[\\x96\\x98-\\x9e\\xa0',
#   3),
#  ('\\xa2\\xa5-\\xac\\xb3-\\xbc\\xbf]|\\xaa[\\xb0-\\xbf]|\\xab[\\x80-\\x8e]|\\xac[\\x80-',
#   2),
#  ('\\x83\\xb4-\\xba\\xbc]|\\xad[\\x82\\xab-\\xb3]|\\xae[\\x80\\x81\\xa2-\\xa5\\xa8\\xa9',
#   3),
#  ('\\xab-\\xad]|\\xaf[\\xa6\\xa8\\xa9\\xad\\xaf-\\xb1]|\\xb0[\\xac-\\xb3\\xb6\\xb7]|\\xb3[',
#   0),
#  ('\\x90-\\x92\\x94-\\xa0\\xa2-\\xa8\\xad\\xb4\\xb8\\xb9]|\\xb7[\\x80-\\xbf])|\\xe2(?:',
#   3),
#  ('\\x80\\x8c|\\x83[\\x90-\\xb0]|\\xb3[\\xaf-\\xb1]|\\xb5\\xbf|\\xb7[\\xa0-\\xbf])|\\xe3(',
#   0),
#  ('?:\\x80[\\xaa-\\xaf]|\\x82[\\x99\\x9a])|\\xea(?:\\x99[\\xaf-\\xb2\\xb4-\\xbd]|\\x9a[',
#   1),
#  ('\\x9e\\x9f]|\\x9b[\\xb0\\xb1]|\\xa0[\\x82\\x86\\x8b\\xa5\\xa6\\xac]|\\xa3[\\x84\\x85',
#   3),
#  ('\\xa0-\\xb1\\xbf]|\\xa4[\\xa6-\\xad]|\\xa5[\\x87-\\x91]|\\xa6[\\x80-\\x82\\xb3\\xb6-',
#   2),
#  ('\\xb9\\xbc\\xbd]|\\xa7\\xa5|\\xa8[\\xa9-\\xae\\xb1\\xb2\\xb5\\xb6]|\\xa9[\\x83\\x8c\\xbc',
#   0),
#  (']|\\xaa[\\xb0\\xb2-\\xb4\\xb7\\xb8\\xbe\\xbf]|\\xab[\\x81\\xac\\xad\\xb6]|\\xaf[\\xa5',
#   2),
#  ('\\xa8\\xad])|\\xef(?:\\xac\\x9e|\\xb8[\\x80-\\x8f\\xa0-\\xaf]|\\xbe[\\x9e\\x9f])|\\xf0',
#   0),
#  ('(?:\\x90(?:\\x87\\xbd|\\x8b\\xa0|\\x8d[\\xb6-\\xba]|\\xa8[\\x81-\\x83\\x85\\x86\\x8c-',
#   1),
#  ('\\x8f\\xb8-\\xba\\xbf]|\\xab[\\xa5\\xa6]|\\xb4[\\xa4-\\xa7]|\\xba[\\xab\\xac]|\\xbb[',
#   2),
#  ('\\xbd-\\xbf]|\\xbd[\\x86-\\x90]|\\xbe[\\x82-\\x85])|\\x91(?:\\x80[\\x81\\xb8-\\xbf]|',
#   1),
#  ('\\x81[\\x80-\\x86\\xb0\\xb3\\xb4\\xbf]|\\x82[\\x80\\x81\\xb3-\\xb6\\xb9\\xba]|\\x83\\x82',
#   0),
#  ('|\\x84[\\x80-\\x82\\xa7-\\xab\\xad-\\xb4]|\\x85\\xb3|\\x86[\\x80\\x81\\xb6-\\xbe]|\\x87',
#   0),
#  ('[\\x89-\\x8c\\x8f]|\\x88[\\xaf-\\xb1\\xb4\\xb6\\xb7\\xbe]|\\x89\\x81|\\x8b[\\x9f\\xa3-',
#   1),
#  ('\\xaa]|\\x8c[\\x80\\x81\\xbb\\xbc\\xbe]|\\x8d[\\x80\\x97\\xa6-\\xac\\xb0-\\xb4]|\\x90[',
#   1),
#  ('\\xb8-\\xbf]|\\x91[\\x82-\\x84\\x86\\x9e]|\\x92[\\xb0\\xb3-\\xb8\\xba\\xbd\\xbf]|\\x93[',
#   0),
#  ('\\x80\\x82\\x83]|\\x96[\\xaf\\xb2-\\xb5\\xbc\\xbd\\xbf]|\\x97[\\x80\\x9c\\x9d]|\\x98[',
#   2),
#  ('\\xb3-\\xba\\xbd\\xbf]|\\x99\\x80|\\x9a[\\xab\\xad\\xb0-\\xb5\\xb7]|\\x9c[\\x9d-\\x9f',
#   2),
#  ('\\xa2-\\xa5\\xa7-\\xab]|\\xa0[\\xaf-\\xb7\\xb9\\xba]|\\xa4[\\xb0\\xbb\\xbc\\xbe]|\\xa5',
#   1),
#  ('\\x83|\\xa7[\\x94-\\x97\\x9a\\x9b\\xa0]|\\xa8[\\x81-\\x8a\\xb3-\\xb8\\xbb-\\xbe]|\\xa9[',
#   0),
#  ('\\x87\\x91-\\x96\\x99-\\x9b]|\\xaa[\\x8a-\\x96\\x98\\x99]|\\xb0[\\xb0-\\xb6\\xb8-\\xbd',
#   1),
#  ('\\xbf]|\\xb2[\\x92-\\xa7\\xaa-\\xb0\\xb2\\xb3\\xb5\\xb6]|\\xb4[\\xb1-\\xb6\\xba\\xbc',
#   3),
#  ('\\xbd\\xbf]|\\xb5[\\x80-\\x85\\x87]|\\xb6[\\x90\\x91\\x95\\x97]|\\xbb[\\xb3\\xb4]|\\xbc',
#   0),
#  ('[\\x80\\x81\\xb6-\\xba]|\\xbd[\\x80\\x82])|\\x93\\x91[\\x80\\x87-\\x95]|\\x96(?:\\xab[',
#   0),
#  ('\\xb0-\\xb4]|\\xac[\\xb0-\\xb6]|\\xbd\\x8f|\\xbe[\\x8f-\\x92]|\\xbf\\xa4)|\\x9b\\xb2[',
#   1),
#  ('\\x9d\\x9e]|\\x9c(?:\\xbc[\\x80-\\xad\\xb0-\\xbf]|\\xbd[\\x80-\\x86])|\\x9d(?:\\x85[',
#   1),
#  ('\\xa5\\xa7-\\xa9\\xae-\\xb2\\xbb-\\xbf]|\\x86[\\x80-\\x82\\x85-\\x8b\\xaa-\\xad]|\\x89[',
#   0),
#  ('\\x82-\\x84]|\\xa8[\\x80-\\xb6\\xbb-\\xbf]|\\xa9[\\x80-\\xac\\xb5]|\\xaa[\\x84\\x9b-',
#   2),
#  ('\\x9f\\xa1-\\xaf])|\\x9e(?:\\x80[\\x80-\\x86\\x88-\\x98\\x9b-\\xa1\\xa3\\xa4\\xa6-\\xaa',
#   0),
#  (']|\\x82\\x8f|\\x84[\\xb0-\\xb6]|\\x8a\\xae|[\\x8b\\x93][\\xac-\\xaf]|\\xa3[\\x90-\\x96',
#   0),
#  (']|\\xa5[\\x84-\\x8a])|\\x9f\\x8f[\\xbb-\\xbf])|\\xf3\\xa0(?:\\x80[\\xa0-\\xbf]|[\\x81',
#   0),
#  ('\\x84-\\x86][\\x80-\\xbf]|\\x87[\\x80-\\xaf]))|\\xe2\\x80\\x8d|(?:\\xe0(?:\\xa4[\\x83',
#   0),
#  ('\\xbb\\xbe\\xbf]|\\xa5[\\x80\\x89-\\x8c\\x8e\\x8f]|[\\xa6\\xb4][\\x82\\x83\\xbf]|[\\xa7',
#   0),
#  ('\\xad][\\x80\\x87\\x88\\x8b\\x8c]|[\\xa8\\xaa][\\x83\\xbe\\xbf]|\\xa9\\x80|\\xab[\\x80',
#   1),
#  ('\\x89\\x8b\\x8c]|[\\xac\\xb6][\\x82\\x83]|[\\xae\\xbd]\\xbf|\\xaf[\\x81\\x82\\x86-\\x88',
#   0),
#  ('\\x8a-\\x8c]|\\xb0[\\x81-\\x83]|\\xb1[\\x81-\\x84]|\\xb2[\\x82\\x83\\xbe]|\\xb3[\\x80',
#   1),
#  ('\\x81\\x83\\x84\\x87\\x88\\x8a\\x8b\\xb3]|\\xb5[\\x80\\x86-\\x88\\x8a-\\x8c]|\\xb7[\\x90',
#   0),
#  ('\\x91\\x98-\\x9e\\xb2\\xb3]|[\\xb8\\xba]\\xb3|\\xbc[\\xbe\\xbf])|\\xe1(?:\\x80[\\xb1',
#   2),
#  ('\\xbb\\xbc]|\\x81[\\x96\\x97]|\\x82\\x84|\\x9c[\\x95\\xb4]|\\x9e[\\xb6\\xbe\\xbf]|\\x9f',
#   0),
#  ('[\\x80-\\x85\\x87\\x88]|\\xa4[\\xa3-\\xa6\\xa9-\\xab\\xb0\\xb1\\xb3-\\xb8]|\\xa8[\\x99',
#   1),
#  ('\\x9a]|\\xa9[\\x95\\x97\\xad-\\xb2]|\\xac[\\x84\\xbb\\xbd-\\xbf]|\\xad[\\x80\\x81\\x83',
#   1),
#  ('\\x84]|\\xae[\\x82\\xa1\\xa6\\xa7\\xaa]|\\xaf[\\xa7\\xaa-\\xac\\xae\\xb2\\xb3]|\\xb0[',
#   2),
#  ('\\xa4-\\xab\\xb4\\xb5]|\\xb3[\\xa1\\xb7])|\\xea(?:\\xa0[\\xa3\\xa4\\xa7]|\\xa2[\\x80',
#   2),
#  ('\\x81\\xb4-\\xbf]|\\xa3[\\x80-\\x83]|\\xa5[\\x92\\x93]|\\xa6[\\x83\\xb4\\xb5\\xba\\xbb',
#   1),
#  ('\\xbe\\xbf]|\\xa7\\x80|\\xa8[\\xaf\\xb0\\xb3\\xb4]|\\xa9\\x8d|\\xab[\\xab\\xae\\xaf\\xb5',
#   0),
#  (']|\\xaf[\\xa3\\xa4\\xa6\\xa7\\xa9\\xaa\\xac])|\\xf0(?:\\x91(?:[\\x80\\xa5][\\x80\\x82]',
#   0),
#  ('|\\x82[\\x82\\xb0-\\xb2\\xb7\\xb8]|\\x84\\xac|\\x85[\\x85\\x86]|\\x86[\\x82\\xb3-\\xb5',
#   1),
#  ('\\xbf]|\\x87[\\x80\\x8e]|\\x88[\\xac-\\xae\\xb2\\xb3\\xb5]|\\x8b[\\xa0-\\xa2]|\\x8c[',
#   2),
#  ('\\x82\\x83\\xbf]|\\x8d[\\x81-\\x84\\x87\\x88\\x8b-\\x8d\\xa2\\xa3]|\\x90[\\xb5-\\xb7]|',
#   1),
#  ('\\x91[\\x80\\x81\\x85]|\\x92[\\xb1\\xb2\\xb9\\xbb\\xbc\\xbe]|[\\x93\\xbd]\\x81|\\x96[',
#   2),
#  ('\\xb0\\xb1\\xb8-\\xbb\\xbe]|\\x98[\\xb0-\\xb2\\xbb\\xbc\\xbe]|\\x9a[\\xac\\xae\\xaf\\xb6',
#   0),
#  (']|\\x9c\\xa6|\\xa0[\\xac-\\xae\\xb8]|\\xa4[\\xb1-\\xb5\\xb7\\xb8\\xbd]|\\xa7[\\x91-',
#   3),
#  ('\\x93\\x9c-\\x9f\\xa4]|\\xa8\\xb9|\\xa9[\\x97\\x98]|\\xaa\\x97|\\xb0[\\xaf\\xbe]|\\xb2[',
#   0),
#  ('\\xa9\\xb1\\xb4]|\\xb6[\\x8a-\\x8e\\x93\\x94\\x96]|\\xbb[\\xb5\\xb6]|\\xbc[\\x83\\xb4',
#   2),
#  ('\\xb5\\xbe\\xbf])|\\x96(?:\\xbd[\\x91-\\xbf]|\\xbe[\\x80-\\x87]|\\xbf[\\xb0\\xb1])|',
#   2),
#  ('\\x9d\\x85[\\xa6\\xad])))*', 0)]

# %%
nudge_enabled = False
with open("part.py", "wt") as f:
    f.write(f"{varname} = (\n")
    for i, (line, nudge) in enumerate(undecorated):
        f.write("    b'")
        f.write(line)
        f.write("'")
        if nudge and nudge_enabled:
            f.write(nudge * "#")
        f.write("\n")
    f.write(")")

with open("raw.py", "wt") as f:
    f.write(f"{varname} = b'")
    f.write(bin_remaining)
    f.write("'\n")

# %%
import part

def length(string: bytes) -> int:
    '''Finds the length of a string'''
    import re
    return len(re.findall(part.pattern, string))

tests = [
    " 😀😀😀👨‍👩‍👧‍👦👨‍👩‍👧‍👦😀😀",
    "hello",
    "こんにちは",
    "à̀̀̀̀",
    "🇫🇮🇫🇮",
]

for test in tests:
    print(length(test.encode("utf-8")), grapheme.length(test))
# Out:
# 8 8
# 5 5
# 5 5
# 1 1
# 2 2
